# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score
from datacleaner import autoclean

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv(r'D:\2025 lessons\AI+ML course amaliyot\Datasets\car price USA\audi.csv')

# %%
df.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
y = df['price']
X = df.drop(columns=['price'])
num_cols = X.select_dtypes(include='number').columns
cat_cols = X.select_dtypes(exclude='number').columns

# %%
cat_cols
# Out:
# Index(['model', 'transmission', 'fuelType'], dtype='object')

# %%
numeric_pipeline = Pipeline([
    ('scaling', StandardScaler())
])

# %%
numeric_pipeline
# Out:
# Pipeline(steps=[('scaling', StandardScaler())])

# %%
category_pipeline = Pipeline([
    ('encoding', OneHotEncoder(handle_unknown='ignore'))
])

# %%
category_pipeline
# Out:
# Pipeline(steps=[('encoding', OneHotEncoder(handle_unknown='ignore'))])

# %%
preprocessing = ColumnTransformer([
    ('numeric feature', numeric_pipeline, num_cols),
    ('categorical feature', category_pipeline, cat_cols)
])

preprocessing
# Out:
# ColumnTransformer(transformers=[('numeric feature',
#                                  Pipeline(steps=[('scaling',
#                                                   StandardScaler())]),
#                                  Index(['year', 'mileage', 'tax', 'mpg', 'engineSize'], dtype='object')),
#                                 ('categorical feature',
#                                  Pipeline(steps=[('encoding',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  Index(['model', 'transmission', 'fuelType'], dtype='object'))])

# %%
model = Pipeline([
    ('preprocessing', preprocessing),
    ('model', DecisionTreeRegressor())

])

model
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('numeric feature',
#                                                   Pipeline(steps=[('scaling',
#                                                                    StandardScaler())]),
#                                                   Index(['year', 'mileage', 'tax', 'mpg', 'engineSize'], dtype='object')),
#                                                  ('categorical feature',
#                                                   Pipeline(steps=[('encoding',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   Index(['model', 'transmission', 'fuelType'], dtype='object'))])),
#                 ('model', DecisionTreeRegressor())])

# %%
X_train, X_test , y_train, y_test = train_test_split(X,y, train_size=0.3, random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('numeric feature',
#                                                   Pipeline(steps=[('scaling',
#                                                                    StandardScaler())]),
#                                                   Index(['year', 'mileage', 'tax', 'mpg', 'engineSize'], dtype='object')),
#                                                  ('categorical feature',
#                                                   Pipeline(steps=[('encoding',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   Index(['model', 'transmission', 'fuelType'], dtype='object'))])),
#                 ('model', DecisionTreeRegressor())])

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([ 9500., 19700., 30600., ..., 14499., 39500., 10995.], shape=(7468,))

# %%
from joblib import dump, load
import os
if not os.path.exists('linear_model.joblib'):
   
    
   
    model.fit(X, y)
    
    dump(model, 'linear_model.joblib')
else:
    model = load('linear_model.joblib')

# %%
import os

# # # Save the model
# # from joblib import dump
# # dump(model, 'model.joblib')

# Add, commit, and push the file to GitHub
# os.system("git add model.joblib")
# os.system("git commit -m 'Auto commit trained model'")
# os.system("git push origin main")
