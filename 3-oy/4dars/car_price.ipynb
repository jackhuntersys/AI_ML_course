# %%
import pandas as pd
from joblib import dump,load
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_squared_error

# %%
df = pd.read_csv(r'D:\2025 lessons\AI+ML course amaliyot\Datasets\car price USA\audi.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10668 non-null  object
#  1   year          10668 non-null  int64
#  2   price         10668 non-null  int64
#  3   transmission  10668 non-null  object
#  4   mileage       10668 non-null  int64
#  5   fuelType      10668 non-null  object
#  6   tax           10668 non-null  int64
#  7   mpg           10668 non-null  float64
#  8   engineSize    10668 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 750.2+ KB

# %%
y = df['price']
x = pd.DataFrame(df.drop(columns=['price']))

# %%
numeric_feature = x.select_dtypes('float64').columns 
categoric_feature = x.select_dtypes('object').columns

# cat_feature = ['transmission', 'fuelType']
# num_feature = ['year', 'mileage', 'tax', 'mpg','engineSize']

# %%
cat_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# %%
cat_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder', OneHotEncoder(handle_unknown='ignore'))])

# %%
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# %%
preproccessing = ColumnTransformer([
    ('num', num_pipeline, numeric_feature),
    ('cat', cat_pipeline, categoric_feature)
])

# %%
preproccessing
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['mpg', 'engineSize'], dtype='object')),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  Index(['model', 'transmission', 'fuelType'], dtype='object'))])

# %%
model_pipe = Pipeline([
    ('preproccessing', preproccessing),
    ('model', RandomForestRegressor())
])

# %%
model_pipe
# Out:
# Pipeline(steps=[('preproccessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['mpg', 'engineSize'], dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
model_pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preproccessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['mpg', 'engineSize'], dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
# ...

# %%
y_pred = model_pipe.predict(x_test)
mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test, y_pred)
print(mse ,'\n', r2)
# Out:
# 11812998.016232828
#  0.9136182156074519

# %%
from joblib import dump, load
dump(model_pipe, 'car_price_model.joblib')
# Out:
# ['car_price_model.joblib']

# %%
import os
print("Saving to:", os.getcwd())
# Out:
# Saving to: C:\Program Files\Microsoft VS Code
